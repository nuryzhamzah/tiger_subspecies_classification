# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = '/content/drive/MyDrive/tiger_datasets'

# %%
# !pip install icrawler

import os
import shutil
from icrawler.builtin import BingImageCrawler

#Search terms per tiger subspecies
search_map = {
    "bengal_tiger": [
        "Bengal tiger in the wild", "Royal Bengal tiger", "Bengal tiger jungle",
        "Bengal tiger India", "Bengal tiger reserve", "Bengal tiger habitat",
        "Bengal tiger close up", "Bengal tiger face"
    ],
    "siberian_tiger": [
        "Siberian tiger snow", "Amur tiger in forest", "Siberian tiger snow habitat",
        "Amur tiger close up", "Siberian tiger walking in snow", "Siberian tiger wildlife", "Siberian tiger hunting"
    ],
    "south_china_tiger": [
        "South China tiger", "rare South China tiger", "South China tiger zoo",
        "South China tiger endangered", "South China tiger nature",
        "South China tiger resting", "South China tiger photos"
    ],
    "sumatran_tiger": [
        "Sumatran tiger rainforest", "wild Sumatran tiger", "Sumatran tiger jungle",
        "Sumatran tiger close up", "Sumatran tiger Indonesia", "Sumatran tiger walking", "Sumatran tiger conservation"
    ],
    "indochinese_tiger": [
        "Indochinese tiger jungle", "Indochinese tiger", "Indochinese tiger forest",
        "Indochinese tiger Thailand", "Indochinese tiger prey", "Indochinese tiger photos", "Indochinese tiger resting"
    ],
    "malayan_tiger": [
        "Malayan tiger Malaysia", "Harimau Malaya", "Malayan tiger forest",
        "Harimau Malaya wildlife", "Malayan tiger face",
        "Malayan tiger national park", "Malayan tiger Malaysia jungle"
    ]
}

#Save location
base_path = '/content/drive/MyDrive/tiger_datasets'
images_per_term = 200

#Main download loop (no deduplication)
for subspecies, terms in search_map.items():
    folder_name = subspecies.lower().replace(" ", "_")
    save_dir = os.path.join(base_path, folder_name)
    os.makedirs(save_dir, exist_ok=True)
    print(f"\n Saving to: {save_dir}")

    for term in terms:
        print(f"Downloading {images_per_term} for: {term}")
        temp_dir = os.path.join(save_dir, term.replace(" ", "_"))
        os.makedirs(temp_dir, exist_ok=True)

        crawler = BingImageCrawler(storage={'root_dir': temp_dir})
        crawler.crawl(keyword=term, max_num=images_per_term)

        for fname in os.listdir(temp_dir):
            src_path = os.path.join(temp_dir, fname)
            if not os.path.isfile(src_path):
                continue

            try:
                base_name = f"{term.replace(' ', '_')}_{fname}"
                dst_path = os.path.join(save_dir, base_name)
                name, ext = os.path.splitext(base_name)
                count = 1
                while os.path.exists(dst_path):
                    dst_path = os.path.join(save_dir, f"{name}_{count}{ext}")
                    count += 1

                shutil.move(src_path, dst_path)

            except Exception as e:
                print(f"Error with {fname}: {e}")
                if os.path.exists(src_path):
                    os.remove(src_path)

        shutil.rmtree(temp_dir, ignore_errors=True)

print("\n All tiger images downloaded.")

# %%
# !pip install imagehash

# %%
import os
from PIL import Image
import imagehash
from collections import defaultdict
import sys

def clean_and_standardize_images(input_dir, output_dir, target_size=(224, 224)):
    os.makedirs(output_dir, exist_ok=True)
    hash_dict = defaultdict(list)
    processed = 0
    skipped = 0

    for filename in os.listdir(input_dir):
        file_path = os.path.join(input_dir, filename)

        if not filename.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff', '.webp', '.jfif')):
            print(f"Skipping non-image: {filename}")
            skipped += 1
            continue

        try:
            img = Image.open(file_path)
            if img.mode != 'RGB':
                img = img.convert('RGB')
            img = img.resize(target_size, Image.Resampling.LANCZOS)

            img_hash = str(imagehash.average_hash(img))
            if img_hash in hash_dict:
                print(f"Duplicate: {filename} matches {hash_dict[img_hash]}")
                skipped += 1
                continue

            hash_dict[img_hash].append(filename)
            save_path = os.path.join(output_dir, f"processed_{os.path.splitext(filename)[0]}.jpg")
            img.save(save_path, 'JPEG', quality=95)
            processed += 1

        except Exception as e:
            print(f"Error processing {filename}: {e}")
            skipped += 1

    return processed, skipped

def verify_dataset(directory):
    corrupted = []

    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        try:
            with Image.open(file_path) as img:
                img.verify()
                if img.size != (224, 224):
                    corrupted.append(f"{filename} - Wrong size: {img.size}")
        except:
            corrupted.append(f"{filename} - Corrupted file")

    return corrupted

def process_all_subspecies(base_input_dir, base_output_dir):
    if not os.path.exists(base_input_dir):
        print(f" Input directory '{base_input_dir}' does not exist.")
        print("Please make sure your raw tiger dataset is available in that folder.")
        sys.exit(1)

    subspecies_dirs = [d for d in os.listdir(base_input_dir) if os.path.isdir(os.path.join(base_input_dir, d))]
    total_processed = 0
    total_skipped = 0

    print(f"\n Found {len(subspecies_dirs)} tiger subspecies to process...")

    for subspecies in subspecies_dirs:
        print(f"\n Processing: {subspecies}")
        input_dir = os.path.join(base_input_dir, subspecies)
        output_dir = os.path.join(base_output_dir, subspecies)

        processed, skipped = clean_and_standardize_images(input_dir, output_dir)
        total_processed += processed
        total_skipped += skipped

        print(f"{subspecies} done — Processed: {processed}, Skipped: {skipped}")

        corrupted = verify_dataset(output_dir)
        if corrupted:
            print(f"Corrupted or invalid images in {subspecies}:")
            for item in corrupted:
                print(f"  - {item}")
        else:
            print(f"All images in {subspecies} verified OK!")

    return total_processed, total_skipped

# Define dataset directories
base_input_directory = "/content/drive/MyDrive/tiger_datasets"            # Raw downloaded images
base_output_directory = "/content/drive/MyDrive/tiger_datasets_cleaned"   # Cleaned and standardized images

if __name__ == "__main__":
    total_processed, total_skipped = process_all_subspecies(base_input_directory, base_output_directory)

    print("\n All processing complete!")
    print(f"Total images processed: {total_processed}")
    print(f"Total images skipped: {total_skipped}")

# %%
# !unzip "/content/drive/MyDrive/tiger_datasets_cleaned.zip" -d "/content/drive/MyDrive/tiger_datasets_cleaned"
# Out:
# Archive:  /content/drive/MyDrive/tiger_datasets_cleaned.zip
#    creating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/
#    creating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_001.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_002.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_003.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_004.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_005.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_006.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_007.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_008.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_009.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_010.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_011.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_012.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_013.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_014.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_015.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_016.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_017.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_018.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_019.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_020.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_021.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_022.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_023.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_024.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_025.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_026.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_027.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_028.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_029.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_030.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_031.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_032.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_033.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_034.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_035.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_036.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_037.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_038.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_039.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_040.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_041.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_042.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_043.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_044.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_045.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_046.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_047.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_048.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_049.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_050.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_051.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_052.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_053.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_054.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_055.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_056.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_057.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_058.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_059.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_060.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_061.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_062.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_063.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_064.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_065.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_066.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_067.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_068.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_069.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_070.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_071.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_072.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_073.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_074.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_075.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_076.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_077.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_078.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_079.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_080.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_081.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_082.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_083.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_084.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_085.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_086.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_087.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_088.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_089.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_090.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_091.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_092.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_093.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_094.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_095.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_096.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_097.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_098.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_099.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_100.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_101.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_102.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_103.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_104.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_105.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_106.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_107.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_108.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_109.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_110.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_111.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_112.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_113.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_114.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_115.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_116.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_117.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_118.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_119.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_120.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_121.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_122.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_123.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_124.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_125.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_126.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_127.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_128.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_129.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_130.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_131.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_132.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_133.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_134.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_135.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_136.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_137.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_138.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_139.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_140.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_141.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_142.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_143.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_144.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_145.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_146.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_147.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_148.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_149.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_150.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_151.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_152.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_153.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_154.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_155.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_156.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_157.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_158.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_159.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_160.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_161.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_162.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_163.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_164.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_165.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_166.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_167.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_168.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_169.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_170.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_171.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_172.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_173.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_174.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_175.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_176.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_177.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_178.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_179.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_180.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_181.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_182.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_183.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_184.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_185.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_186.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_187.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_188.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_189.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_190.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_191.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_192.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_193.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_194.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_195.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_196.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_197.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_198.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_199.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_200.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_201.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_202.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_203.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_204.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_205.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_206.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_207.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_208.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_209.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_210.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_211.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_212.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_213.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_214.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_215.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_216.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_217.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_218.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_219.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_220.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_221.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_222.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_223.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_224.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_225.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_226.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_227.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_228.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_229.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_230.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_231.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_232.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_233.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_234.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_235.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_236.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_237.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_238.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_239.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_240.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_241.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_242.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_243.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_244.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_245.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_246.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_247.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_248.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_249.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_250.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_251.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_252.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_253.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_254.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_255.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_256.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_257.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_258.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_259.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_260.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_261.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_262.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_263.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_264.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_265.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_266.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_267.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_268.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_269.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_270.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_271.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_272.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_273.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_274.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_275.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_276.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_277.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_278.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_279.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_280.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_281.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_282.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_283.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_284.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_285.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_286.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_287.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_288.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_289.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_290.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_291.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_292.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_293.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_294.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_295.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_296.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_297.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_298.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_299.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_300.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_301.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_302.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_303.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_304.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_305.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_306.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_307.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_308.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_309.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_310.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_311.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_312.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_313.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_314.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_315.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_316.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_317.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_318.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_319.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_320.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_321.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_322.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_323.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_324.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_325.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_326.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_327.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_328.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_329.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_330.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_331.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_332.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_333.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_334.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_335.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_336.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_337.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_338.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_339.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_340.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_341.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_342.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_343.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_344.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_345.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_346.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_347.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_348.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_349.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_350.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_351.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_352.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_353.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_354.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_355.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_356.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_357.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_358.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_359.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_360.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_361.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_362.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_363.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_364.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_365.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_366.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_367.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_368.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_369.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_370.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_371.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_372.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_373.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_374.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_375.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_376.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_377.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_378.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_379.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_380.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_381.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_382.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_383.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_384.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_385.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_386.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_387.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_388.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_389.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_390.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_391.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_392.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_393.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_394.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_395.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_396.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_397.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_398.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_399.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_400.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_401.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_402.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_403.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/bengal_tiger/bengal_tiger_404.jpg
# ...
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_666.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_667.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_668.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_669.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_670.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_671.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_672.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_673.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_674.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_675.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_676.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_677.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_678.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_679.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_680.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_681.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_682.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_683.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_684.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_685.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_686.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_687.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_688.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_689.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_690.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_691.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_692.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_693.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_694.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_695.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_696.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_697.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_698.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_699.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_700.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_701.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_702.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_703.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_704.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_705.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_706.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_707.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_708.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_709.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_710.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_711.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_712.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_713.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_714.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_715.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_716.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_717.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_718.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_719.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_720.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_721.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_722.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_723.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_724.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_725.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_726.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_727.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_728.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_729.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_730.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_731.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_732.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_733.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_734.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_735.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_736.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_737.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_738.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_739.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_740.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_741.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_742.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_743.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_744.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_745.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_746.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_747.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_748.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_749.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_750.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_751.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_752.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_753.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_754.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_755.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_756.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_757.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_758.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_759.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_760.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_761.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_762.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_763.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_764.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_765.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_766.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_767.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_768.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_769.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_770.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_771.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_772.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_773.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_774.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_775.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_776.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_777.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_778.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_779.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_780.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_781.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_782.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_783.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_784.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_785.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_786.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_787.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_788.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_789.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_790.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_791.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_792.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_793.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_794.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_795.jpg
#   inflating: /content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned/sumatran_tiger/sumatran_tiger_796.jpg

# %%
import os

# Your base folder in Google Drive
base_path = '/content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned'

# Optional: valid image extensions to include
valid_exts = ('.jpg', '.jpeg', '.png', '.webp')

print("Image Count per Subspecies:\n")

for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)
    if os.path.isdir(folder_path):
        num_images = len([f for f in os.listdir(folder_path) if f.lower().endswith(valid_exts)])
        print(f"{folder}: {num_images} images")
# Out:
# Image Count per Subspecies:
#
# south_china_tiger: 455 images
# sumatran_tiger: 796 images
# malayan_tiger: 604 images
# siberian_tiger: 442 images
# bengal_tiger: 580 images
# indochinese_tiger: 615 images

# %%
import os

#  Path to the dataset with subspecies folders
base_dir = '/content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned'  # or 'tiger_datasets' if unprocessed

#  Loop through each subspecies folder
for subspecies in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, subspecies)

    # Make sure it's a directory
    if not os.path.isdir(folder_path):
        continue

    print(f"\n Renaming images in: {subspecies}")

    # Subspecies name becomes the prefix
    prefix = subspecies.lower().replace(" ", "_")

    # Get and sort all image files
    image_files = sorted([
        f for f in os.listdir(folder_path)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp'))
    ])

    # Rename each image using the format: subspecies_###.ext
    for idx, filename in enumerate(image_files, start=1):
        ext = os.path.splitext(filename)[1].lower()
        new_name = f"{prefix}_{idx:03d}{ext}"  # e.g., siberian_tiger_001.jpg
        src = os.path.join(folder_path, filename)
        dst = os.path.join(folder_path, new_name)

        try:
            os.rename(src, dst)
        except Exception as e:
            print(f"Failed to rename {filename} → {new_name}: {e}")

print("\n All renaming complete.")
# Out:
#  Renaming images in: bengal_tiger
#
#  Renaming images in: indochinese_tiger
#
#  Renaming images in: malayan_tiger
#
#  Renaming images in: siberian_tiger
#
#  Renaming images in: south_china_tiger
#
#  Renaming images in: sumatran_tiger
#
#  All renaming complete.

# %%
import os
import random
import shutil

# Set seed for reproducibility
random.seed(42)

# Path to the cleaned and renamed dataset
base_dir = '/content/drive/MyDrive/tiger_datasets_cleaned/tiger_datasets_cleaned'
split_base_dir = '/content/drive/MyDrive/tiger_datasets'

# Split ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Loop through each subspecies
for subspecies in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, subspecies)

    if not os.path.isdir(folder_path):
        continue

    print(f"\n Processing: {subspecies}")

    prefix = subspecies.lower().replace(" ", "_")

    image_files = sorted([
        f for f in os.listdir(folder_path)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp'))
    ])

    # Step 1: Rename images
    for idx, filename in enumerate(image_files, start=1):
        ext = os.path.splitext(filename)[1].lower()
        new_name = f"{prefix}_{idx:03d}{ext}"
        src = os.path.join(folder_path, filename)
        dst = os.path.join(folder_path, new_name)
        try:
            os.rename(src, dst)
        except Exception as e:
            print(f"Failed to rename {filename} → {new_name}: {e}")

    # Step 2: Reload the renamed list and shuffle
    all_files = sorted([
        f for f in os.listdir(folder_path)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp'))
    ])
    random.shuffle(all_files)

    n = len(all_files)
    n_train = int(train_ratio * n)
    n_val = int(val_ratio * n)

    splits = {
        "train": all_files[:n_train],
        "val": all_files[n_train:n_train + n_val],
        "test": all_files[n_train + n_val:]
    }

    # Step 3: Copy to new split directories
    for split, files in splits.items():
        split_dir = os.path.join(split_base_dir, split, subspecies)
        os.makedirs(split_dir, exist_ok=True)

        for fname in files:
            src_path = os.path.join(folder_path, fname)
            dst_path = os.path.join(split_dir, fname)
            shutil.copy2(src_path, dst_path)

        print(f" {split.upper()} set: {len(files)} images")

print("\n🎉 All subspecies split into train/val/test.")
# Out:
#  Processing: south_china_tiger
#  TRAIN set: 318 images
#  VAL set: 68 images
#  TEST set: 69 images
#
#  Processing: sumatran_tiger
#  TRAIN set: 557 images
#  VAL set: 119 images
#  TEST set: 120 images
#
#  Processing: malayan_tiger
#  TRAIN set: 422 images
#  VAL set: 90 images
#  TEST set: 92 images
#
#  Processing: siberian_tiger
#  TRAIN set: 309 images
#  VAL set: 66 images
#  TEST set: 67 images
#
#  Processing: bengal_tiger
#  TRAIN set: 406 images
#  VAL set: 87 images
#  TEST set: 87 images
#
#  Processing: indochinese_tiger
#  TRAIN set: 430 images
#  VAL set: 92 images
#  TEST set: 93 images
#
# 🎉 All subspecies split into train/val/test.
